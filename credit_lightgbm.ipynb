# %%
import logging

import numpy as np
import toad
import pandas as pd
from sklearn.model_selection import StratifiedKFold, ParameterGrid
from sklearn.metrics import roc_auc_score
from lightgbm import LGBMClassifier

import config

# %%
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter()
sh = logging.StreamHandler()
sh.setFormatter(formatter)
logger.addHandler(sh)

is_eda = False
is_gridsearch = False

# %%
# 读数据
train_public = pd.read_csv(config.TRAIN_PUBLIC_PATH)
train_internet = pd.read_csv(config.TRAIN_INTERNET_PATH)
test_public = pd.read_csv(config.TEST_PUBLIC_PATH)

# %%
# 标签列重命名
train_internet = train_internet.rename(columns={'is_default': 'isDefault'})

# %%
# 特征工程
## 找相同的特征
common_cols = []
for col in train_public.columns:
    if col in train_internet.columns:
        common_cols.append(col)
logger.info(len(common_cols))

## 只取相同的列
train_public_less = train_public.loc[:, common_cols]
train_internet_less = train_internet.loc[:, common_cols]
test_public_less = test_public.loc[:, common_cols[:-1]]
# Out:
# 36

# %%
# EDA
if is_eda:
    train_public_detect = toad.detect(train_public_less)
    train_internet_detect = toad.detect(train_internet_less)
    train_public_quality = toad.quality(train_public_less, 'isDefault')
    train_internet_quality = toad.quality(train_internet_less, 'isDefault')

# %%
# 处理类别特征
def class_apply(x):
    if x == 'A':
        return 1
    elif x == 'B':
        return 2
    elif x == 'C':
        return 3
    elif x == 'D':
        return 4
    elif x == 'E':
        return 5
    elif x == 'F':
        return 6
    elif x == 'G':
        return 7
    else:
        return 0


def employer_type_apply(x):
    if x == '普通企业':
        return 1
    elif x == '幼教与中小学校':
        return 2
    elif x == '高等教育机构':
        return 3
    elif x == '政府机构':
        return 4
    elif x == '上市企业':
        return 5
    elif x == '世界五百强':
        return 6
    else:
        return 0


def industry_apply(x):
    if x == '金融业':
        return 1
    elif x == '公共服务、社会组织':
        return 2
    elif x == '文化和体育业':
        return 3
    elif x == '信息传输、软件和信息技术服务业':
        return 4
    elif x == '制造业':
        return 5
    elif x == '住宿和餐饮业':
        return 6
    elif x == '建筑业':
        return 7
    elif x == '电力、热力生产供应业':
        return 8
    elif x == '房地产业':
        return 9
    elif x == '交通运输、仓储和邮政业':
        return 10
    elif x == '批发和零售业':
        return 11
    elif x == '农、林、牧、渔业':
        return 12
    elif x == '采矿业':
        return 13
    elif x == '国际组织':
        return 14
    else:
        return 0


def work_year_apply(x):
    if x == '< 1 year':
        return 1
    elif x == '1 year':
        return 2
    elif x == '2 years':
        return 3
    elif x == '3 years':
        return 4
    elif x == '4 years':
        return 5
    elif x == '5 years':
        return 6
    elif x == '6 years':
        return 7
    elif x == '7 years':
        return 8
    elif x == '8 years':
        return 9
    elif x == '9 years':
        return 10
    elif x == '10+ years':
        return 11
    else:
        return 0

# %%
train_public_less['class'] = train_public_less['class'].apply(class_apply)
train_public_less['employer_type'] = train_public_less['employer_type'].apply(employer_type_apply)
train_public_less['industry'] = train_public_less['industry'].apply(industry_apply)
train_public_less['work_year'] = train_public_less['work_year'].apply(work_year_apply)

train_internet_less['class'] = train_internet_less['class'].apply(class_apply)
train_internet_less['employer_type'] = train_internet_less['employer_type'].apply(employer_type_apply)
train_internet_less['industry'] = train_internet_less['industry'].apply(industry_apply)
train_internet_less['work_year'] = train_internet_less['work_year'].apply(work_year_apply)

test_public_less['class'] = test_public_less['class'].apply(class_apply)
test_public_less['employer_type'] = test_public_less['employer_type'].apply(employer_type_apply)
test_public_less['industry'] = test_public_less['industry'].apply(industry_apply)
test_public_less['work_year'] = test_public_less['work_year'].apply(work_year_apply)

# %%
# 去除非数值类型特征
drop_cols = list(train_public_less.select_dtypes('object').columns) + ['isDefault']

# 构造模型数据
X_train = train_public_less.drop(columns=drop_cols).values
y_train = train_public_less['isDefault'].values

X_internet = train_internet_less.drop(columns=drop_cols).values
y_internet = train_internet_less['isDefault'].values

X_test = test_public_less.drop(columns=drop_cols[:-1]).values

# %%
is_gridsearch = True
# 交叉验证lightgbm
if is_gridsearch:
    grid = [{
        'num_leaves': [5, 10, 20, 30],
        'learning_rate': [0.01, 0.03, 0.1, 0.3],
        'reg_alpha': [0, 0.1, 0.2],
        'reg_lambda': [0, 0.1, 0.2]
    }]
    score_detail = []
    best_score = 0
    for param in ParameterGrid(grid):
        logger.info(param)
        param['random_state'] = 1
        scores = []
        skf = StratifiedKFold(n_splits=5, random_state=1, shuffle=True)
        count = 0
        for train_index, valid_index in skf.split(X_train, y_train):
            count += 1
            logger.info(f'train k fold {count}')
            X_more, X_less = X_train[train_index], X_train[valid_index]
            y_more, y_less = y_train[train_index], y_train[valid_index]
            X_more_internet = np.concatenate([X_more, X_internet])
            y_more_internet = np.concatenate([y_more, y_internet])
            clf = LGBMClassifier(**param)
            clf.fit(X_more_internet, y_more_internet)
            y_proba = clf.predict_proba(X_less)[:, 1]
            score = roc_auc_score(y_less, y_proba)
            scores.append(score)
        scores = np.array(scores)
        logger.info(scores)
        logger.info(scores.mean())
        if scores.mean() > best_score:
            best_score = scores.mean()
            logger.info(f'best score {best_score}')
        score_detail.append([param, scores, scores.mean()])
    best_param = sorted(score_detail, key=lambda x: x[2])[-1][0]
# Out:
# {'learning_rate': 0.01, 'num_leaves': 5, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.85440991 0.82812589 0.83809693 0.83663109 0.82682257]
# 0.8368172799207312
# best score 0.8368172799207312
# {'learning_rate': 0.01, 'num_leaves': 5, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.85416488 0.82812589 0.83809693 0.83663109 0.82682257]
# 0.8367682729381304
# {'learning_rate': 0.01, 'num_leaves': 5, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.85416488 0.82812589 0.83809693 0.83663109 0.82682257]
# 0.8367682729381304
# {'learning_rate': 0.01, 'num_leaves': 5, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.85416488 0.82812589 0.83809693 0.83663109 0.82682257]
# 0.8367682729381304
# {'learning_rate': 0.01, 'num_leaves': 5, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.85416488 0.82812589 0.83809693 0.83663109 0.82682257]
# 0.8367682729381304
# {'learning_rate': 0.01, 'num_leaves': 5, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.85416488 0.82812589 0.83809693 0.83663109 0.82682257]
# 0.8367682729381304
# {'learning_rate': 0.01, 'num_leaves': 5, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.85416488 0.82812589 0.83809693 0.83663109 0.82682257]
# 0.8367682729381304
# {'learning_rate': 0.01, 'num_leaves': 5, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.85416488 0.82812589 0.83809693 0.83663109 0.82682257]
# 0.8367682729381304
# {'learning_rate': 0.01, 'num_leaves': 5, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.85416488 0.82812589 0.83809693 0.83663109 0.82682257]
# 0.8367682729381304
# {'learning_rate': 0.01, 'num_leaves': 10, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86107594 0.84406837 0.84389336 0.84827124 0.83951459]
# 0.8473646984157439
# best score 0.8473646984157439
# {'learning_rate': 0.01, 'num_leaves': 10, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86066367 0.84405406 0.84428324 0.84728896 0.83951459]
# 0.8471609030990942
# {'learning_rate': 0.01, 'num_leaves': 10, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86066367 0.84405406 0.84428324 0.84885115 0.83951459]
# 0.8474733412047664
# best score 0.8474733412047664
# {'learning_rate': 0.01, 'num_leaves': 10, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86066367 0.84405406 0.84389336 0.84785906 0.83951459]
# 0.8471969467868987
# {'learning_rate': 0.01, 'num_leaves': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86066367 0.84405406 0.84428324 0.84885115 0.83951459]
# 0.8474733412047664
# {'learning_rate': 0.01, 'num_leaves': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86066367 0.84405406 0.84428324 0.84885115 0.83951459]
# 0.8474733412047664
# {'learning_rate': 0.01, 'num_leaves': 10, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86066367 0.84405406 0.84389336 0.84785906 0.83951459]
# 0.8471969467868987
# {'learning_rate': 0.01, 'num_leaves': 10, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86066367 0.84405406 0.84428324 0.84885115 0.83951459]
# 0.8474733412047664
# {'learning_rate': 0.01, 'num_leaves': 10, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86066367 0.84405406 0.84428324 0.84885115 0.83951459]
# 0.8474733412047664
# {'learning_rate': 0.01, 'num_leaves': 20, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86863178 0.84782974 0.8479679  0.85681199 0.84711588]
# 0.8536714580146556
# best score 0.8536714580146556
# {'learning_rate': 0.01, 'num_leaves': 20, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8683465  0.84782795 0.84764226 0.85642657 0.8471141 ]
# 0.8534714758804846
# {'learning_rate': 0.01, 'num_leaves': 20, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8678922  0.84737008 0.84805623 0.85641587 0.84766189]
# 0.8534792518762504
# {'learning_rate': 0.01, 'num_leaves': 20, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8683465  0.84737187 0.84764226 0.85642657 0.84764405]
# 0.8534862483583481
# {'learning_rate': 0.01, 'num_leaves': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86804155 0.84737365 0.84805623 0.85642657 0.84764405]
# 0.8535084090531914
# {'learning_rate': 0.01, 'num_leaves': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86848779 0.84737365 0.84763691 0.85641587 0.84717566]
# 0.8534179758592284
# {'learning_rate': 0.01, 'num_leaves': 20, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86804155 0.84737365 0.8478653  0.85642657 0.84764405]
# 0.8534702241562103
# {'learning_rate': 0.01, 'num_leaves': 20, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86848958 0.84737187 0.84785817 0.85641587 0.84764761]
# 0.8535566191534072
# {'learning_rate': 0.01, 'num_leaves': 20, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86848958 0.84737365 0.84787066 0.85685303 0.84766903]
# 0.8536511900723751
# {'learning_rate': 0.01, 'num_leaves': 30, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86893315 0.84820981 0.85420061 0.86251653 0.84353471]
# 0.855478961268679
# best score 0.855478961268679
# {'learning_rate': 0.01, 'num_leaves': 30, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86871405 0.84838867 0.85439956 0.86253348 0.84354006]
# 0.8555151643329605
# best score 0.8555151643329605
# {'learning_rate': 0.01, 'num_leaves': 30, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86911558 0.84933125 0.85377236 0.8625656  0.84376935]
# 0.8557108293266642
# best score 0.8557108293266642
# {'learning_rate': 0.01, 'num_leaves': 30, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8688938  0.84843875 0.85451465 0.86254418 0.8438889 ]
# 0.8556560576765072
# {'learning_rate': 0.01, 'num_leaves': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86899128 0.84932857 0.85383303 0.86257809 0.84387016]
# 0.8557202261964785
# best score 0.8557202261964785
# {'learning_rate': 0.01, 'num_leaves': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86898055 0.8491041  0.85382233 0.86253259 0.84340356]
# 0.8555686242660329
# {'learning_rate': 0.01, 'num_leaves': 30, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86924794 0.84961921 0.85383839 0.86216412 0.84392191]
# 0.8557583134089098
# best score 0.8557583134089098
# {'learning_rate': 0.01, 'num_leaves': 30, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86894746 0.84870436 0.85382233 0.86216769 0.84350527]
# 0.8554294191283558
# {'learning_rate': 0.01, 'num_leaves': 30, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86874177 0.84875891 0.85406678 0.86250047 0.84363374]
# 0.8555403335653835
# {'learning_rate': 0.03, 'num_leaves': 5, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86931591 0.84691399 0.8541221  0.85589395 0.84419938]
# 0.854089062550976
# {'learning_rate': 0.03, 'num_leaves': 5, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86931591 0.84691041 0.8541221  0.85589395 0.84419581]
# 0.854087633384181
# {'learning_rate': 0.03, 'num_leaves': 5, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8694581  0.84691041 0.8541221  0.85589395 0.84419581]
# 0.8541160717426974
# {'learning_rate': 0.03, 'num_leaves': 5, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8694581  0.84691041 0.8541221  0.85589395 0.84419581]
# 0.8541160717426974
# {'learning_rate': 0.03, 'num_leaves': 5, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8694581  0.84691041 0.8541221  0.85589395 0.84419581]
# 0.8541160717426974
# {'learning_rate': 0.03, 'num_leaves': 5, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8694581  0.84691041 0.8541221  0.85589395 0.84419581]
# 0.8541160717426974
# {'learning_rate': 0.03, 'num_leaves': 5, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8694581  0.84691041 0.8541221  0.85589395 0.84419581]
# 0.8541160717426974
# {'learning_rate': 0.03, 'num_leaves': 5, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8694581  0.84691041 0.8541221  0.85589395 0.84419581]
# 0.8541160717426974
# {'learning_rate': 0.03, 'num_leaves': 5, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8694581  0.84691041 0.85412566 0.85589395 0.84419045]
# 0.8541157148745013
# {'learning_rate': 0.03, 'num_leaves': 10, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87262835 0.85251134 0.8569592  0.86171714 0.84824091]
# 0.8584113870809047
# best score 0.8584113870809047
# {'learning_rate': 0.03, 'num_leaves': 10, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87262835 0.85250776 0.85696098 0.86139239 0.84823912]
# 0.8583457216388142
# {'learning_rate': 0.03, 'num_leaves': 10, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87262656 0.85251134 0.85696277 0.86133173 0.84765654]
# 0.8582177852375231
# {'learning_rate': 0.03, 'num_leaves': 10, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87262835 0.85251134 0.85696098 0.86139239 0.84765475]
# 0.8582295627349993
# {'learning_rate': 0.03, 'num_leaves': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87262477 0.85251134 0.85696098 0.86133351 0.84765475]
# 0.8582170706541257
# {'learning_rate': 0.03, 'num_leaves': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87262477 0.85251134 0.85696277 0.86132637 0.84765654]
# 0.8582163569177335
# {'learning_rate': 0.03, 'num_leaves': 10, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87332142 0.85251134 0.85696098 0.86133351 0.8472506 ]
# 0.8582755700786832
# {'learning_rate': 0.03, 'num_leaves': 10, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87331427 0.85251134 0.85696277 0.86132637 0.84765297]
# 0.8583535423915061
# {'learning_rate': 0.03, 'num_leaves': 10, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87331248 0.85251134 0.85696098 0.86133708 0.84764761]
# 0.8583538984126969
# {'learning_rate': 0.03, 'num_leaves': 20, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87655338 0.85642117 0.86172339 0.86512969 0.85120916]
# 0.8622073572736685
# best score 0.8622073572736685
# {'learning_rate': 0.03, 'num_leaves': 20, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87654801 0.85615467 0.86091597 0.86537237 0.85121808]
# 0.8620418201199656
# {'learning_rate': 0.03, 'num_leaves': 20, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87646663 0.85614394 0.86023257 0.86524835 0.85121808]
# 0.8618619149283615
# {'learning_rate': 0.03, 'num_leaves': 20, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87654622 0.85615646 0.86103731 0.86535898 0.85112976]
# 0.8620457456701225
# {'learning_rate': 0.03, 'num_leaves': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87655159 0.85565029 0.8601719  0.86587644 0.85113332]
# 0.8618767098518678
# {'learning_rate': 0.03, 'num_leaves': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87774904 0.85565923 0.86017547 0.86588358 0.85242429]
# 0.8623783241042998
# best score 0.8623783241042998
# {'learning_rate': 0.03, 'num_leaves': 20, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8777562  0.85565923 0.8601719  0.8658693  0.85158833]
# 0.8622089935332792
# {'learning_rate': 0.03, 'num_leaves': 20, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87775441 0.85565744 0.86017547 0.86587644 0.85159904]
# 0.8622125605212293
# {'learning_rate': 0.03, 'num_leaves': 20, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87776156 0.85576118 0.86017726 0.86436154 0.85158655]
# 0.8619296165560675
# {'learning_rate': 0.03, 'num_leaves': 30, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88017793 0.85591232 0.86477015 0.86629309 0.84717387]
# 0.8628654702378373
# best score 0.8628654702378373
# {'learning_rate': 0.03, 'num_leaves': 30, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87681272 0.85601069 0.86405285 0.86702734 0.84752003]
# 0.8622847261002644
# {'learning_rate': 0.03, 'num_leaves': 30, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87757555 0.85594809 0.86380482 0.86700593 0.84762174]
# 0.8623912259912061
# {'learning_rate': 0.03, 'num_leaves': 30, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87676801 0.85539542 0.86470056 0.86712013 0.84752806]
# 0.862302435399181
# {'learning_rate': 0.03, 'num_leaves': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87745393 0.85614304 0.86399753 0.8670095  0.84714532]
# 0.8623498640076808
# {'learning_rate': 0.03, 'num_leaves': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87693792 0.85630044 0.863853   0.86610662 0.84756821]
# 0.8621532382411573
# {'learning_rate': 0.03, 'num_leaves': 30, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87669468 0.85675652 0.86412243 0.86694348 0.84757   ]
# 0.8624174214999003
# {'learning_rate': 0.03, 'num_leaves': 30, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87639956 0.85620564 0.86392616 0.866873   0.84647263]
# 0.8619753964737005
# {'learning_rate': 0.03, 'num_leaves': 30, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87643891 0.85590874 0.86423306 0.86678646 0.84659575]
# 0.8619925826124358
# {'learning_rate': 0.1, 'num_leaves': 5, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87640582 0.8569014  0.86757335 0.86492003 0.85422826]
# 0.8640057736567407
# best score 0.8640057736567407
# {'learning_rate': 0.1, 'num_leaves': 5, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87639509 0.8569014  0.86756978 0.86492003 0.85422469]
# 0.8640021998927473
# {'learning_rate': 0.1, 'num_leaves': 5, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8763933  0.85690498 0.86751268 0.86492003 0.85422648]
# 0.8639914946938705
# {'learning_rate': 0.1, 'num_leaves': 5, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87639688 0.8569014  0.867568   0.86492003 0.85422291]
# 0.8640018438715569
# {'learning_rate': 0.1, 'num_leaves': 5, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87638972 0.8569014  0.86750911 0.86492182 0.85422469]
# 0.8639893500966723
# {'learning_rate': 0.1, 'num_leaves': 5, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87638972 0.85690319 0.86751447 0.86492539 0.85423005]
# 0.8639925627574424
# {'learning_rate': 0.1, 'num_leaves': 5, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87639151 0.85689782 0.86717187 0.86492003 0.85422469]
# 0.8639211874242146
# {'learning_rate': 0.1, 'num_leaves': 5, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8763933  0.85599638 0.86717187 0.8649236  0.85422826]
# 0.863742684150662
# {'learning_rate': 0.1, 'num_leaves': 5, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87638972 0.85595524 0.86717366 0.86492539 0.85423897]
# 0.8637365962161943
# {'learning_rate': 0.1, 'num_leaves': 10, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87847699 0.86124585 0.86822463 0.87028912 0.85924761]
# 0.867496841613573
# best score 0.867496841613573
# {'learning_rate': 0.1, 'num_leaves': 10, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87872739 0.86102407 0.86836738 0.87028376 0.85835009]
# 0.8673505392052643
# {'learning_rate': 0.1, 'num_leaves': 10, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87906901 0.86026571 0.86837273 0.8702909  0.85762922]
# 0.8671255148894772
# {'learning_rate': 0.1, 'num_leaves': 10, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87872918 0.86027108 0.86968066 0.8703819  0.85793612]
# 0.8673997881422603
# {'learning_rate': 0.1, 'num_leaves': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87872382 0.86026035 0.86897584 0.87100464 0.85691191]
# 0.8671753104238746
# {'learning_rate': 0.1, 'num_leaves': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87915307 0.86025856 0.86919175 0.87101356 0.85695295]
# 0.8673139777182414
# {'learning_rate': 0.1, 'num_leaves': 10, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87897243 0.86025856 0.86966103 0.87101356 0.85664605]
# 0.8673103234887372
# {'learning_rate': 0.1, 'num_leaves': 10, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8788365  0.86025498 0.86870998 0.87060138 0.85663534]
# 0.8670076331920373
# {'learning_rate': 0.1, 'num_leaves': 10, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87884186 0.86004214 0.8684227  0.87060673 0.85662999]
# 0.8669086824490979
# {'learning_rate': 0.1, 'num_leaves': 20, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88104718 0.86318646 0.87080122 0.87420218 0.86399039]
# 0.870645484646022
# best score 0.870645484646022
# {'learning_rate': 0.1, 'num_leaves': 20, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8816696  0.86139788 0.87132582 0.87506401 0.86388869]
# 0.870669199435848
# best score 0.870669199435848
# {'learning_rate': 0.1, 'num_leaves': 20, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88370142 0.86350303 0.87398806 0.87555114 0.86259147]
# 0.8718670238843729
# best score 0.8718670238843729
# {'learning_rate': 0.1, 'num_leaves': 20, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88337769 0.86195592 0.87396664 0.87447161 0.86300365]
# 0.8713551026599514
# {'learning_rate': 0.1, 'num_leaves': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88193967 0.86258549 0.87264623 0.87713563 0.86377806]
# 0.8716170179376419
# {'learning_rate': 0.1, 'num_leaves': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88485505 0.86488381 0.87373111 0.87636301 0.86579258]
# 0.8731251138776075
# best score 0.8731251138776075
# {'learning_rate': 0.1, 'num_leaves': 20, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88398759 0.86157316 0.87211628 0.87539768 0.86429908]
# 0.8714747610753232
# {'learning_rate': 0.1, 'num_leaves': 20, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88333119 0.8611904  0.8734242  0.87444485 0.8634658 ]
# 0.8711712878667213
# {'learning_rate': 0.1, 'num_leaves': 20, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8821704  0.86116894 0.87183079 0.8742111  0.86383337]
# 0.8706429199341553
# {'learning_rate': 0.1, 'num_leaves': 30, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88568853 0.86587826 0.87484632 0.87806527 0.86769825]
# 0.8744353289285414
# best score 0.8744353289285414
# {'learning_rate': 0.1, 'num_leaves': 30, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88398044 0.86156779 0.87271939 0.87847032 0.86500747]
# 0.8723490822266934
# {'learning_rate': 0.1, 'num_leaves': 30, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88404304 0.86277866 0.87339744 0.8775835  0.86623866]
# 0.8728082609264931
# {'learning_rate': 0.1, 'num_leaves': 30, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88529147 0.86410578 0.87304771 0.87987995 0.86654557]
# 0.8737740953482582
# {'learning_rate': 0.1, 'num_leaves': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88310583 0.86261769 0.87352234 0.87853099 0.86410816]
# 0.8723770009525152
# {'learning_rate': 0.1, 'num_leaves': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88566707 0.86240306 0.87380605 0.87795108 0.86616907]
# 0.8731992659427654
# {'learning_rate': 0.1, 'num_leaves': 30, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88111693 0.86121544 0.87439845 0.87946777 0.86621368]
# 0.8724824554891393
# {'learning_rate': 0.1, 'num_leaves': 30, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88522708 0.86487487 0.87322793 0.8785185  0.86438473]
# 0.8732466210063684
# {'learning_rate': 0.1, 'num_leaves': 30, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88353866 0.86308093 0.8744841  0.87829545 0.86451321]
# 0.872782470704767
# {'learning_rate': 0.3, 'num_leaves': 5, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88091124 0.85613231 0.86723254 0.86955754 0.85806638]
# 0.866380002818552
# {'learning_rate': 0.3, 'num_leaves': 5, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87848057 0.85817665 0.86849585 0.86833526 0.86109262]
# 0.8669161927641053
# {'learning_rate': 0.3, 'num_leaves': 5, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87714987 0.85835372 0.86694526 0.86832813 0.86107656]
# 0.8663707087102136
# {'learning_rate': 0.3, 'num_leaves': 5, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8816535  0.85778674 0.86640639 0.86968066 0.85782014]
# 0.8666694873081984
# {'learning_rate': 0.3, 'num_leaves': 5, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8792425  0.8583412  0.86732711 0.86965746 0.86166718]
# 0.8672470914624668
# {'learning_rate': 0.3, 'num_leaves': 5, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87757555 0.86104374 0.86745558 0.86833526 0.86105872]
# 0.8670937716860696
# {'learning_rate': 0.3, 'num_leaves': 5, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87887584 0.85887778 0.87200208 0.8696646  0.85927438]
# 0.8677389363021829
# {'learning_rate': 0.3, 'num_leaves': 5, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87680467 0.85918899 0.86889376 0.86742882 0.86590856]
# 0.8676449602497105
# {'learning_rate': 0.3, 'num_leaves': 5, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87667232 0.85924443 0.86869392 0.86996794 0.86091419]
# 0.8670985586202733
# {'learning_rate': 0.3, 'num_leaves': 10, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87508585 0.85176461 0.86407783 0.87110991 0.86117827]
# 0.8646432943792896
# {'learning_rate': 0.3, 'num_leaves': 10, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87480862 0.85141226 0.86474695 0.86971813 0.85919944]
# 0.8639770801795017
# {'learning_rate': 0.3, 'num_leaves': 10, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87389824 0.85679408 0.86718436 0.87358836 0.85970797]
# 0.8662346046922084
# {'learning_rate': 0.3, 'num_leaves': 10, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86129951 0.85877225 0.86617621 0.87073877 0.857449  ]
# 0.8628871476497293
# {'learning_rate': 0.3, 'num_leaves': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87026027 0.86012799 0.86085531 0.87309945 0.85951527]
# 0.8647716579655421
# {'learning_rate': 0.3, 'num_leaves': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87655785 0.85917468 0.86737172 0.87537806 0.8640582 ]
# 0.868508100753254
# {'learning_rate': 0.3, 'num_leaves': 10, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87398767 0.86203819 0.86590142 0.87122411 0.8576881 ]
# 0.8661678980322123
# {'learning_rate': 0.3, 'num_leaves': 10, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87616973 0.85946085 0.86060907 0.87457332 0.86170644]
# 0.8665038806847353
# {'learning_rate': 0.3, 'num_leaves': 10, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87339565 0.86268208 0.86856723 0.87338673 0.8622578 ]
# 0.8680578965618334
# {'learning_rate': 0.3, 'num_leaves': 20, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87580844 0.8558998  0.854669   0.86997329 0.85506869]
# 0.8622838411242135
# {'learning_rate': 0.3, 'num_leaves': 20, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88159627 0.85708562 0.85947066 0.86789096 0.86156547]
# 0.8655217969275043
# {'learning_rate': 0.3, 'num_leaves': 20, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87682077 0.85966833 0.86682571 0.87559753 0.86452926]
# 0.8686883206073567
# {'learning_rate': 0.3, 'num_leaves': 20, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.8710866  0.85456373 0.86386727 0.86609235 0.85714923]
# 0.8625518352778185
# {'learning_rate': 0.3, 'num_leaves': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87474781 0.85861486 0.8598757  0.86590142 0.8602183 ]
# 0.8638716174721794
# {'learning_rate': 0.3, 'num_leaves': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87857357 0.85974166 0.86974489 0.87393988 0.86122645]
# 0.8686452906117316
# {'learning_rate': 0.3, 'num_leaves': 20, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87183064 0.85214736 0.85977578 0.87201279 0.85238861]
# 0.8616310371182813
# {'learning_rate': 0.3, 'num_leaves': 20, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87302362 0.85499835 0.86878849 0.87289961 0.85825731]
# 0.8655934754375953
# {'learning_rate': 0.3, 'num_leaves': 20, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87249421 0.86014945 0.87034086 0.87399341 0.86372096]
# 0.8681397774693869
# {'learning_rate': 0.3, 'num_leaves': 30, 'reg_alpha': 0, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87281257 0.85879371 0.86233631 0.8747464  0.86301079]
# 0.8663399567616066
# {'learning_rate': 0.3, 'num_leaves': 30, 'reg_alpha': 0, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87943388 0.86002604 0.86447752 0.86895265 0.86348542]
# 0.8672751019540135
# {'learning_rate': 0.3, 'num_leaves': 30, 'reg_alpha': 0, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87383743 0.85903517 0.87301202 0.87172373 0.85922085]
# 0.8673658387687677
# {'learning_rate': 0.3, 'num_leaves': 30, 'reg_alpha': 0.1, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87520926 0.85254443 0.86611376 0.87373646 0.85474037]
# 0.8644688567009251
# {'learning_rate': 0.3, 'num_leaves': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87572974 0.86057335 0.86699522 0.87051038 0.85789152]
# 0.8663400397885592
# {'learning_rate': 0.3, 'num_leaves': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87244949 0.86357637 0.87169696 0.86948973 0.86359427]
# 0.8681613637755419
# {'learning_rate': 0.3, 'num_leaves': 30, 'reg_alpha': 0.2, 'reg_lambda': 0}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.86774554 0.86039449 0.85985608 0.86592283 0.85909951]
# 0.862603689593152
# {'learning_rate': 0.3, 'num_leaves': 30, 'reg_alpha': 0.2, 'reg_lambda': 0.1}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87183959 0.86071464 0.86398682 0.86891517 0.86249155]
# 0.865589554989896
# {'learning_rate': 0.3, 'num_leaves': 30, 'reg_alpha': 0.2, 'reg_lambda': 0.2}
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.87460651 0.8607683  0.86285912 0.86745915 0.86311963]
# 0.8657625443196977

# %%
best_param
# Out:
# {'learning_rate': 0.1,
#  'num_leaves': 30,
#  'reg_alpha': 0,
#  'reg_lambda': 0,
#  'random_state': 1}

# %%
# best_param: 
# {'learning_rate': 0.1,
#  'num_leaves': 30,
#  'reg_alpha': 0,
#  'reg_lambda': 0,
#  'random_state': 1}
skf = StratifiedKFold(n_splits=5, random_state=1, shuffle=True)
count = 0
scores = []
for train_index, valid_index in skf.split(X_train, y_train):
    count += 1
    logger.info(f'train k fold {count}')
    X_more, X_less = X_train[train_index], X_train[valid_index]
    y_more, y_less = y_train[train_index], y_train[valid_index]
    X_more_internet = np.concatenate([X_more, X_internet])
    y_more_internet = np.concatenate([y_more, y_internet])
    clf = LGBMClassifier(num_leaves=30, random_state=1)
    clf.fit(X_more_internet, y_more_internet)
    y_proba = clf.predict_proba(X_less)[:, 1]
    score = roc_auc_score(y_less, y_proba)
    scores.append(score)
scores = np.array(scores)
logger.info(scores)
logger.info(scores.mean())
# Out:
# train k fold 1
# train k fold 2
# train k fold 3
# train k fold 4
# train k fold 5
# [0.88568853 0.86587826 0.87484632 0.87806527 0.86769825]
# 0.8744353289285414

# %%
X_final_train = np.concatenate([X_train, X_internet])
# pd.concat([X_train, X_internet])
y_final_train = np.concatenate([y_train, y_internet])

# %%
clf_ex = LGBMClassifier(num_leaves=30, random_state=1)
clf_ex.fit(X_final_train, y_final_train)
y_proba = clf.predict_proba(X_test)[:, 1]

# %%
submission = pd.DataFrame({'id': test_public['loan_id'], 'isDefault': y_proba})
submission.to_csv('submission.csv', index=None)
